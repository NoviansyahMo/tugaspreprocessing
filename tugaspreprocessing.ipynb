# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/Tugas"

# %%
# %cd /content/drive/My Drive/Tugas
# Out:
# /content/drive/My Drive/Tugas

# %%
pip install Sastrawi
# Out:
# ...
#      |████████████████████████████████| 215kB 9.3MB/s
# ...

# %%
import pandas as PD
import numpy as NP

# %%
df_ir = PD.read_excel("hasilcrawlingtrue.xlsx")
df_ir
# Out:
#                                                 Link  ...                                            Halaman
# 0       https://www.guru99.com/python-tutorials.html  ...  [<a aria-label="Guru99" class="g-logo" href="/...
# 1                  https://www.w3schools.com/python/  ...  [<a class="w3schools-logo notranslate" href="/...
# 2                   http://jagocoding.com/tag/python  ...  [<a class="navbar-brand" href="/" id="logo"><i...
# 3  https://yadishare.wordpress.com/2018/01/16/tut...  ...  [<a class="skip-link screen-reader-text" href=...
# 4  https://www.dewaweb.com/blog/belajar-coding-un...  ...  [<a class="skip-link screen-reader-text" href=...
# 5       https://belajarphp.net/belajar-html-dan-css/  ...  [<a href="https://belajarphp.net/">\n<img alt=...
# 6  https://www.kodingindonesia.com/belajar-pemrog...  ...  [<a href="https://www.kodingindonesia.com/">\n...
# 7  https://badoystudio.com/belajar-android-untuk-...  ...  [<a class="sr-only sr-only-focusable" href="#c...
# ...

# %%
df_ir.isnull().sum()
# Out:
# Link       0
# Data       2
# Halaman    0
# dtype: int64

# %%
df_ir = df_ir.dropna()

# %%
df_ir
# Out:
#                                                 Link  ...                                            Halaman
# 0       https://www.guru99.com/python-tutorials.html  ...  [<a aria-label="Guru99" class="g-logo" href="/...
# 1                  https://www.w3schools.com/python/  ...  [<a class="w3schools-logo notranslate" href="/...
# 2                   http://jagocoding.com/tag/python  ...  [<a class="navbar-brand" href="/" id="logo"><i...
# 3  https://yadishare.wordpress.com/2018/01/16/tut...  ...  [<a class="skip-link screen-reader-text" href=...
# 5       https://belajarphp.net/belajar-html-dan-css/  ...  [<a href="https://belajarphp.net/">\n<img alt=...
# 6  https://www.kodingindonesia.com/belajar-pemrog...  ...  [<a href="https://www.kodingindonesia.com/">\n...
# 7  https://badoystudio.com/belajar-android-untuk-...  ...  [<a class="sr-only sr-only-focusable" href="#c...
# 9  https://www.kompasiana.com/deniasilvia95/5c527...  ...  [<a href="https://www.kompasiana.com/"><img cl...
# ...

# %%
 from bs4 import BeautifulSoup
import re
import nltk
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

def prepros_word(raw_text):
    
    print("----------------------Kalimat Asli----------------------")
    print(raw_text)
    
    #1. Case folding
    lowertext = raw_text.lower()
    print("\n----------------------Case Folding----------------------")
    print(lowertext)
    
    #2. Filtering
    deleteurl = re.sub(r"http\S+", "", lowertext)
    letters_only = re.sub("[^a-zA-Z]", " ",str(deleteurl))
    spacetext = letters_only.strip()
    print("\n----------------------Filtering----------------------")
    print(spacetext)
 
    #3. Tokenisasi
    words = spacetext.split()
    print("\n----------------------Tokenisasi----------------------")
    print(words)
    
    
    #4. Stemming
    stem_words=[]
    stem1 = StemmerFactory()
    stemmer = stem1.create_stemmer()
    for word in words:
        stem_text = stemmer.stem(word)
        stem_words.append(stem_text)
    print("\n----------------------Stemming----------------------")
    print(stem_words)
        
    #5. Remove stop words
    stopword_factory = StopWordRemoverFactory()
    stopwords = stopword_factory.get_stop_words()
    filtered_text = [word for word in stem_words if word not in stopwords]
    print("\n----------------------Remove Stopword----------------------")
    print(filtered_text)

    print("\n----------------------Hasil Akhir Setelah PreProcessing----------------------")
    # 5. Join the words back into one string separated by space & return, remove the short text
    return(" ".join(w for w in filtered_text if len(w)>2))

# %%
ex_text = open("hanyadata.txt", "r+", encoding = "latin-1").read()

# %%
prepros_word(ex_text)
# Out:
# ----------------------Kalimat Asli----------------------
# Data
# ...

# %%
df_ir["clean_text"] = df_ir["Data"].apply(prepros_word)
df_ir
# Out:
# ----------------------Kalimat Asli----------------------
# ...
